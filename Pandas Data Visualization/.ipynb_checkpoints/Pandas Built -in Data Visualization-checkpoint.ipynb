# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1=pd.read_csv("df1",index_col=0)
df2=pd.read_csv("df2")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["A"].hist()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %%
df1["A"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("bmh")
df1["A"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("dark_background")
df1["A"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("fivethirtyeight")
df1["A"].hist()
# Out:
# <AxesSubplot:>

# %%
plt.style.use("ggplot")

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1.plot.hist(bins=50,stacked=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1["A"].plot.hist(bins=50,stacked=False)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(y="B",figsize=(12,3),lw=1)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x="A",y="B")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x="A",y="B",c="C",cmap="inferno")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x="A",y="B",s=df1["C"],cmap="inferno")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x="A",y="B",s=df1["C"]*200,cmap="inferno",)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()#by=df2["a"]
# Out:
# <AxesSubplot:>

# %%
df=pd.DataFrame(np.random.randn(1000,2),columns=["A","B"])

# %%
df.plot.hexbin(x="A",y="B",gridsize=25,cmap="inferno")
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2["a"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
